# %% [markdown]
# ## Welcome to the SBML Lab
#
# You are joining the **Systems Biology & Metabolic Engineering Laboratory (SBML)** at KAIST, led by Prof. Donghyuk Kim. The lab studies how bacteria control gene expression — specifically, which proteins bind to DNA to turn genes on or off, and what that tells us about how *E. coli* responds to its environment.
#
# The main experimental technique is **ChIP-exo**: a method that pinpoints exactly where DNA-binding proteins (called transcription factors) attach to the bacterial chromosome. The data produced — millions of short DNA sequence reads — must be processed computationally before any biology can be learned from it.
#
# Over the next 6 weeks you will learn to run that computational pipeline using **Claude Code**, a command-line AI tool that works alongside your code. You don't need to memorize every command or flag — but you do need to understand what each step does and why. Claude Code helps you get there faster.
#
# > **Modules at a glance:**
# > - M1 (this notebook): Learn Claude Code basics
# > - M2: Parse and filter genomic annotation files
# > - M3: Run the full ChIP-exo alignment pipeline
# > - M4: Discover DNA-binding motifs from real published data
# > - M5: Design and run your own analysis on the same dataset
#
# ---

# %% [markdown]
# # Module 1 — Claude Code Basics
# ## What is Claude Code and Why It Changes Your Workflow
#
# **Prerequisites:** Basic Python (variables, loops, functions, file I/O)
# **Goal:** Understand what Claude Code is, how to prompt it well, and complete your first three exercises using it.
#
# ---

# %% [markdown]
# ## 1. What is Claude Code?
#
# Claude Code is a **command-line tool** — not a chatbot you open in a browser. It runs in your terminal alongside your code.
#
# Key differences from a chatbot:
#
# | Chatbot | Claude Code |
# |---|---|
# | You paste code in manually | It reads your files directly |
# | It can only suggest code | It can write, run, and edit files |
# | No project context | It sees your full directory structure |
# | New session = blank slate | It holds context across your session |
#
# ### Starting Claude Code
#
# Open your terminal in a project directory and type:
#
# ```bash
# claude
# ```
#
# That's it. Claude Code starts, reads your project structure, and waits for your first prompt. From that point, you're having a conversation with an agent that has full access to your files.

# %% [markdown]
# ## 2. How to Prompt Effectively
#
# Prompting Claude Code is a skill. Three principles to build that skill:
#
# ### Principle 1: Be specific about the task
# Vague prompts produce vague code. Say exactly what input the function takes, what it should return, and any edge cases that matter. If you want a script that reads a GFF3 file and counts features by type, say that — not just "write a GFF parser."
#
# ### Principle 2: Give context about your files and environment
# Claude Code can see your files, but it works faster when you point it in the right direction. Mention which file to look at, what format the data is in, or what library you're already using. The more relevant context you give, the less it has to guess.
#
# ### Principle 3: Iterate — your first prompt is a draft
# Don't expect a perfect solution on the first try. Start with a clear first prompt to get a working skeleton, then follow up with refinements: *"That works, but can you also handle malformed lines without crashing?"* Each follow-up shapes the output closer to what you need.
#
# ---
#
# Claude can be wrong. Not often, but it happens — a flag slightly off, a parameter it stated confidently that doesn't match the man page, a biological detail that sounds right but isn't. You'll start to develop a sense for when something needs a second look: when a result surprises you, when a command behaves differently than Claude described, when a claim about the biology doesn't match what you read in the paper. When that feeling comes up, check. It becomes instinct.
#
# > **Your turn:** You will write your own prompts in the exercises below. There are no example prompts here intentionally — the goal is for you to practice formulating them.

# %% [markdown]
# ## 3. Three Modes of Use
#
# Most of your interactions with Claude Code will fall into one of three patterns:
#
# | Mode | When to use |
# |---|---|
# | **Write code** | You need a new script, function, or pipeline step and want a working starting point |
# | **Explain code** | You encounter code you didn't write (or wrote six months ago) and need to understand what it does |
# | **Debug code** | Something broke — an error, unexpected output, or a test failure — and you need to find the cause |
#
# You don't have to declare which mode you're in. Just describe the situation naturally and Claude Code figures out what you need.

# %% [markdown]
# ## 4. Three Tools You'll Use Every Session
#
# Three custom skills are provided for this training. A **skill** is a Markdown file with structured instructions that Claude follows when you invoke it by name. Skill files live in `.claude/commands/`.
#
# | Invocation | When to use it |
# |---|---|
# | `/log` | End of every session — saves a structured log to `log/session-log.md` covering what you worked on, what broke, and what to pick up next |
# | `/debug` | When something breaks — walks through a 5-step root-cause diagnosis: reproduce → localize → fix → verify → document. Prevents random guessing |
# | `/explain` | When you encounter an unfamiliar concept or tool — gives an explanation anchored to the lab's organism, file formats, and workflows |
#
# Skills are not magic — they are just Markdown files. You can read them, copy them, and modify them. In Exercise 4 you will do exactly that.
#
# > **Skill files:** `.claude/commands/log.md`, `.claude/commands/debug.md`, `.claude/commands/explain.md`

# %% [markdown]
# ---
#
# > **Note on the first exercise:** The task below — printing a triangle of stars — has nothing to do with bioinformatics. That is intentional. The goal here is to practice *how to talk to Claude Code*, not to solve a biology problem. Use it as a low-stakes warm-up: focus on forming clear prompts, following up to refine the output, and asking Claude Code to explain what it wrote.
#
# ---

# %% [markdown]
# ## Exercise 1 — Write Code with Claude Code
#
# **Task:** Use Claude Code to write a Python script that prints a right-triangle of stars.
# For example, with `n = 5` the output should be:
#
# ```
# *
# **
# ***
# ****
# *****
# ```
#
# Once it works, refine it with **two follow-up prompts**:
# 1. Ask Claude Code to make the character customizable — so you can pass `'#'` or `'+'` instead of `'*'`
# 2. Ask Claude Code to explain what `range()` does in the script
#
# Paste the final version in the code cell below. Add a comment at the top noting what changed between your first version and the final version.
#
#
# > **Explain it:** after your code runs, write 1–2 sentences on *how it works and why Claude chose that approach*. You should be able to defend every line — if you can't explain it, you don't yet understand it.

# %%
# Your final star-triangle script here
# Comment: what changed between your first version and the final version?
symbol = input("what symbol? ") # input()은 항상 문자열을 반환한다. symbol은 그대로 반환하면 됨.
length = int(input("For how long? "))   # 그런데 length는 숫자를 반환해야 하므로, int()로 wrap했음.

for i in range(1, length + 1):  # 길이가 1씩 증가하는 출력문을 만들기 위해 range()를 사용. range()는 마지막 숫자를 포함하지 않으므로 length + 1로 설정.
    print(symbol * i)   # i개 만큼 symbol 출력
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# ## Exercise 2 — Debug Code with Claude Code
#
# The script below is broken. It should print a countdown from 5 to 1, then print `Go!`
# — but the output is wrong.
#
# **Task:**
# 1. Run the cell as-is and observe what it actually prints.
# 2. Open Claude Code and use `/debug` to diagnose what is wrong.
# 3. Fix the script so it prints the correct countdown.
# 4. Time yourself: how long did it take with Claude Code's help? How long do you think it would have taken alone?
#
# Write the fixed version and your time estimate in the cells below.
#
#
# > **Explain it:** after fixing it, write 1–2 sentences on *what each bug was and why your fix works*. Understanding the bug matters more than the patch.

# %%
# This script should print:
# 5
# 4
# 3
# 2
# 1
# Go!

for i in range(5):
    print(i)
print('Go!')
# Out:
# 0
# 1
# 2
# 3
# 4
# Go!

# %%
# Fixed version here
for i in range(5, 0, -1):   # 5에서 시작해서, 0 앞에서 끝남, 한 step 당 -1씩 증가
    print(i)
print('Go!')
# Out:
# 5
# 4
# 3
# 2
# 1
# Go!

# %% [markdown]
# > **Answer**
# >
# > *Time with Claude Code:* 9s
# >
# > *How long alone (estimate):* 5 min

# %% [markdown]
# ## Exercise 3 — Read the Skill Files
#
# Open the three skill files:
# - `.claude/commands/log.md`
# - `.claude/commands/debug.md`
# - `.claude/commands/explain.md`
#
# Read each one carefully and answer the following questions in the Markdown cell below:
#
# 1. **What does `/log` save?** List the sections that appear in a session log.
# 2. **What are the 5 steps of `/debug`?** Name them in order.
# 3. **What does `/explain` anchor its explanations to?** Where does it tie abstract concepts back to?
#
# Write your answers in your own words — do not copy-paste directly from the skill files.

# %% [markdown]
# > **Answer**
# >
# > *(Write your answers here)*
# >
# > 1. `/log` saves: What happened in this session - what is accomplished, what was broken and/or made the user struggle, what new understanding is learned
# >
# > 2. The 5 steps of `/debug`:
#     1. Reproduce the bug by gathering context through questions
#     2. pinpoint the cause
#     3. provide a minimal fix
#     4. inform the user how to verify the fix
#     5. remind the user to use the /log command to document the issue and the fix
# >
# > 3. `/explain` anchors explanations to: SBML lab's context

# %% [markdown]
# ## Exercise 4 — Create Your Own Skill
#
# You've used `/log`, `/debug`, and `/explain`. Now you'll make one yourself.
#
# **Step 1 — Read how a skill is structured**
#
# Open `.claude/commands/explain.md` and look at how it's written. Every skill has the same skeleton:
#
# ```markdown
# ---
# name: skill-name
# description: one-line description shown in the /skills list
# ---
#
# # Skill Title
#
# ## Purpose
# What this skill does and when to use it.
#
# ## Process
# Step-by-step instructions Claude will follow.
# ```
#
# That's all a skill is — a Markdown file with instructions. Claude reads it and follows the steps when you invoke the skill by name.
#
# **Step 2 — Create `/summarize`**
#
# Create a new file at `.claude/commands/summarize.md` that implements a `/summarize` skill. When invoked, `/summarize` should:
#
# 1. Look at what has been done in the current session (files edited, commands run, questions asked)
# 2. Write a 3-sentence summary covering: (a) what was accomplished, (b) anything that broke or was surprising, (c) what is still open or unfinished
# 3. Print the summary to the terminal so the intern can copy it into a note or share it with their supervisor
#
# Write this skill yourself in plain language — you are writing instructions for Claude to follow, not Python code.
#
# **Step 3 — Test it**
#
# In your Claude Code terminal, run:
# ```
# /summarize
# ```
#
# Check whether the output actually reflects what you did in this session. If it misses something important, refine the skill file and run it again.
#
# Write your final `summarize.md` content in the markdown cell below, and describe in one sentence what you changed after testing.

# %% [markdown]
# > **Answer**
# >
# > *Paste your final `summarize.md` contents here (the markdown source, not a file path):*
# >
# > ```
# ---
# name: summarize
# description: provides a summary of accomplishments and struggles occurred in current session
# ---
#
# # Session Summary
#
# ## Purpose
# Provide a concise 3-sentence summary of what has been done in the current session to inform a supervisor of the user's accomplishment and struggles.
#
# ## Process
# 1. Look at what has been done in the current session — files edited, commands run, questions asked.
# 2. Check the actual work artifacts, not just the chat:
#    - If a notebook is open or was worked on this session, read its code cells and markdown-answer cells directly. Compare each against its placeholder text (e.g. "Your final ... script here", "(Write your answers here)") to tell filled-in work apart from untouched cells.
#    - Run `git status` and `git diff` to see which files were actually modified or created — this can surface changes made outside the chat.
#    - Scan cell outputs for tracebacks, error messages, or failed assertions — these count as struggles even if the intern never mentioned them in chat.
# 3. Write the summary as three separate bullet points, one sentence each, in this format:
#    - Accomplished: <what was accomplished — cite specific exercises/files completed, based on the artifact check above, not just what was discussed>
#    - Broke/surprising: <anything that broke or was surprising — including errors found in cell outputs, not only ones raised in conversation>
#    - Still open: <what is still open or unfinished — explicitly name any exercise/cell still containing placeholder text>
# 4. Print the three bullet points to the terminal so the intern can copy them into a note or share them with their supervisor
#
# > ```
# >
# > *What you changed after testing:*
# 초기에 만든 summarize.md는 chat history만을 보고 세 문장으로 된 산문을 만들었다.
# 테스트 후에 수정하여 notebook과 git status를 cross-check하여 bullet point 형식으로 출력하도록 만들었다.

# %% [markdown]
# ## End of Session
#
# Before you close your terminal, run `/log` in the Claude Code session.
#
# ```
# /log
# ```
#
# This saves a structured session log to `log/session-log.md`. The log captures what you worked on, any decisions you made, files you changed, and what to do next time.
#
# > **This is mandatory at the end of every session.** Over time, your session logs become a searchable record of your work in the lab.
#
# After running `/log`, verify that `log/session-log.md` was created and skim it — does it accurately reflect what you did today?

# %% [markdown]
# ## Git — Commit Your Work
#
# Every session ends with a commit. Run the commands below in your terminal (not in this notebook).
#
# Write your own commit message following the format: `feat(module1): <what you did>`.
# If you're unsure what to write, ask Claude Code to suggest one based on what you worked on.

# %%
# Run these in the terminal (not here):
# git add notebooks/
# git commit -m "..."   # write your own commit message; use Claude Code to help if needed
# git push
