# %% [markdown]
# # **Claude Code Training — Module 5–6: Mini-Project** <a name="module-5-6"></a>
#
# **Intern:** [Your name]
# **Date:** [Start date]
# **Dataset:** [Describe the dataset]

# %% [markdown]
# **Contents:**
# **Part 1: Dataset Exploration ([Go link](#issue-5_1))**
# **Part 2: Literature Context ([Go link](#issue-5_2))**
# **Part 3: Biological Question ([Go link](#issue-5_3))**
# **Part 4: Analysis Plan ([Go link](#issue-5_4))**
# **Part 5: Analysis Execution ([Go link](#issue-5_5))**
# **Part 6: Results ([Go link](#issue-5_6))**
# **Part 7: Report ([Go link](#issue-5_7))**

# %% [markdown]
# ### **# Part 1** <a name="issue-5_1"></a>
# *(Week 5, Days 1–2)*
#
# Start by understanding the dataset before forming a question.
#
# * Checklist:
#   * **Use Claude Code to explore the `data/` directory. Identify all files, their formats, organism, and experiment type. Run any necessary shell commands in the code cell.**
#   * **In the answer sheet: summarize the dataset — what files exist, what format, what organism, what experiment type.**

# %% [markdown]
#   **Answer sheet**
#   >*Please write down your answer on the sheet below.<br/>*
#   **You can use the answer writing sheet by double-clicking the relevant sheet.**
#   ```
#   Answer:
#   ```

# %% [markdown]
# ### **# Part 2** <a name="issue-5_2"></a>
# *(Week 5, Day 2)*
#
# Before forming a question, understand what is already known. Use Claude to find relevant published work and extract any reference gene lists or coordinates.
#
# * Checklist:
#   * **Use Claude to find what is already known about the gene, regulator, or condition in your dataset. Extract any reference gene lists or coordinates from relevant papers. Paste any extracted data in the code cell.**
#   * **In the answer sheet: write 3–5 sentences summarizing the literature context. Cite papers if possible.**

# %% [markdown]
#   **Answer sheet**
#   >*Please write down your answer on the sheet below.<br/>*
#   **You can use the answer writing sheet by double-clicking the relevant sheet.**
#   ```
#   Answer:
#   ```

# %% [markdown]
# ### **# Part 3** <a name="issue-5_3"></a>
# *(Week 5, Days 2–3)*
#
# Propose one specific, answerable biological question. It must be grounded in your literature context and must include the condition, organism, and comparison or threshold.
#
# **Instructor check-in required before proceeding to Part 4.**
#
# * Checklist:
#   * **In the answer sheet: write your biological question. Be specific — include organism, condition, comparison, and any quantitative threshold.**

# %% [markdown]
#   **Answer sheet**
#   >*Please write down your answer on the sheet below.<br/>*
#   **You can use the answer writing sheet by double-clicking the relevant sheet.**
#   ```
#   Answer:
#   ```

# %% [markdown]
# ### **# Part 4** <a name="issue-5_4"></a>
# *(Week 5, Day 3)*
#
# Write your analysis plan independently. Claude Code may be consulted but the plan must be your own thinking.
#
# * Checklist:
#   * **In the answer sheet: write your plain-English analysis plan. Answer: (1) What input data will you use? (2) What steps will you run? (3) What output do you expect? (4) How will you know if the result is meaningful?**
#   * **Use plan mode (Shift+Tab) to generate the pipeline scaffold. Review every proposed step. Paste the reviewed and annotated pipeline in the code cell.**

# %% [markdown]
#   **Answer sheet**
#   >*Please write down your answer on the sheet below.<br/>*
#   **You can use the answer writing sheet by double-clicking the relevant sheet.**
#   ```
#   Answer:
#   ```

# %% [markdown]
# ### **# Part 5** <a name="issue-5_5"></a>
# *(Week 5 Days 4–5 + Week 6 Days 1–3)*
#
# Run your pipeline. Use `/debug` when blocked. Add code cells as needed.
#
# * Checklist:
#   * **Run the pipeline step by step. Add cells as needed below this one.**
#   * **In the answer sheet: document any major decision you made during execution (e.g. a parameter you changed, a step you added or removed, an error you resolved).**

# %% [markdown]
#   **Answer sheet**
#   >*Please write down your answer on the sheet below.<br/>*
#   **You can use the answer writing sheet by double-clicking the relevant sheet.**
#   ```
#   Answer:
#   ```

# %% [markdown]
# ### **# Part 6** <a name="issue-5_6"></a>
# *(Week 6, Days 1–3)*
#
# Generate and document your results. Each figure needs a caption.
#
# * Checklist:
#   * **Generate your figures in the code cell. Add more cells as needed.**
#   * **In the answer sheet: write a 1–2 sentence caption for each figure describing what it shows.**

# %% [markdown]
#   **Answer sheet**
#   >*Please write down your answer on the sheet below.<br/>*
#   **You can use the answer writing sheet by double-clicking the relevant sheet.**
#   ```
#   Answer:
#   ```

# %% [markdown]
# ### **# Part 7** <a name="issue-5_7"></a>
# *(Week 6, Days 4–5)*
#
# Write your analysis report. This is your own writing — Claude Code may be used but is not required.
#
# * Checklist:
#   * **Write the report in the answer sheet above. Submit this notebook as your deliverable.**
#   * **Run `/log` for a final session entry before submitting.**

# %% [markdown]
#   **Answer sheet**
#   >*Please write down your answer on the sheet below.<br/>*
#   **You can use the answer writing sheet by double-clicking the relevant sheet.**
#   ```
#   Answer:
#
#   **Question:**
#
#   **Methods:**
#
#   **Results:**
#
#   **Interpretation:**
#
#   **Limitations:**
#   ```
